# %% [markdown]
# # [GGUF (Georgi Gerganov Unified Format)](https://github.com/unslothai/unsloth?tab=readme-ov-file)
# - GGUF 포맷은 Georgi Gerganov에 의해 개발된 딥러닝 모델 저장용 단일 파일 포맷입니다.
# - 이 포맷은 메타데이터와 텐서 데이터를 저장하며, 다양한 양자화를 지원하여 모델의 크기를 줄이고 추론 속도를 높입니다.
# - GGUF는 주로 GGML 라이브러리 기반 런타임에서 사용되며, CPU에서도 실행 가능하여 큰 유연성과 확장성을 제공합니다.

# %% [markdown]
# ## [GGML이란?](https://www.ibm.com/kr-ko/think/topics/gguf-versus-ggml)
# - 개발자 게오르기 게르가노프(Georgi Gerganov)가 만든 `GGML`은 `GGUF` 바로 이전의 파일 형식입니다.
# - `GGML`은 다양한 하드웨어 플랫폼에서 고성능을 발휘하도록 설계된 텐서 라이브러리였습니다.
# - `GGML`은 표준 하드웨어에서 대규모 언어 모델에 액세스할 수 있도록 하기 위한 초기 노력이었습니다. 그러나 유연성과 확장성 측면에서 제한적이었습니다.
#
# `GGUF`는 `GGML` 제한 사항을 해결하고 이전 모델과의 호환성을 유지하면서 새로운 기능을 추가할 수 있게 합니다. `GGUF`는 주요 변경 사항을 제거하여 최신 버전으로의 전환이 용이하게 하고 다양한 모델을 지원하는 포괄적인 솔루션입니다.

# %% [markdown]
# ## [GGUF 파일에는 두 가지가 기록된다.](https://bitwise-life.tistory.com/4)
# 1. 모델의 Weight Tensor 값과 텐서 정보
#   - Tensor 의 이름
#   - Tensor 의 차원 수
#   - Tensor 의 Shape
#   - Tensor 의 데이터 타입
#   - Tensor 데이터가 위치한 Offset
# 2. Key-Value 형식의 메타데이터
#   - Key는 ASCII 문자와 '.' 으로 계층을 표현한다.
#     - 다음처럼 쓸 수 있다. llama.attention.head_count_kv
#   - 먼저 모델의 세부 정보들이 포함되어야한다. 예를 들어
#     - 입력 토큰 길이 (context length)
#     - 임베딩 크기 (embedding length)
#     - 피드 포워드 길이 (feed forward length)
#   - 여기에 추가로 Tokenizer 의 정보도 단일 파일에 포함되어야한다.
#     - bos token id
#     - eos token id
#     - uknown token id
#     - seperate token id
#     - padding token id
#     - Vocab file

# %% [markdown]
# ## GGUF 장점
# - `단일 파일 구조`: 모델을 하나의 파일로 쉽게 공유할 수 있습니다. 이는 모델의 배포와 사용을 간편하게 만듭니다.
# - `메타데이터와 텐서 데이터`: 파일 내에 모델의 가중치(weight) 텐서 값들과 메타데이터가 Key-Value 형식으로 저장됩니다. 메타데이터는 모델의 구조, 버전, 텐서 개수 등을 포함합니다.
# - `다양한 양자화 지원`: GGUF는 16-bit 부동 소수점(floating point)뿐만 아니라 8-bit, 6-bit, 5-bit, 4-bit, 3-bit, 그리고 2-bit까지의 다양한 양자화된 텐서 타입을 지원합니다. 이는 모델을 더 작게 만들어 추론 속도를 높이고, 메모리 사용을 줄이는 데 유용합니다.

# %% [markdown]
# ## [Unsloth Models](https://docs.unsloth.ai/get-started/all-our-models)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # [예제](https://docs.unsloth.ai/get-started/unsloth-notebooks)

# %% [markdown]
# ## install

# %% [markdown]
# ### Do this only in Colab notebooks!

# %%
# Do this only in Colab notebooks! Otherwise use pip install unsloth
# import torch; v = re.match(r"[0-9\.]{3,}", str(torch.__version__)).group(0)

# xformers = "xformers==" + ("0.0.32.post2" if v == "2.8.0" else "0.0.29.post3")
# !pip install --no-deps bitsandbytes accelerate {xformers} peft trl triton cut_cross_entropy unsloth_zoo
# !pip install sentencepiece protobuf "datasets>=3.4.1,<4.0.0" "huggingface_hub>=0.34.0" hf_transfer
# !pip install --no-deps unsloth
# !pip install transformers==4.55.4
# !pip install --no-deps trl==0.22.2

# %% [markdown]
# ### No Colab notebooks!

# %% [markdown]
# - 설치된 파이썬 버전 확인

# %%
ls /usr/bin/python*
# Out:
# /usr/bin/python3@            /usr/bin/python3.12-config@
# /usr/bin/python3.10*         /usr/bin/python3.13*
# /usr/bin/python3.10-config@  /usr/bin/python3.13-config@
# /usr/bin/python3.11*         /usr/bin/python3.9*
# /usr/bin/python3.11-config@  /usr/bin/python3.9-config@
# /usr/bin/python3.12*

# %% [markdown]
# - 주피터 파이썬 버전 확인

# %%
import sys
print(sys.executable)
# Out:
# /usr/local/bin/python

# %% [markdown]
# - 시스템 파이썬 버전을 주피터 파이썬 버전으로 변경
#     ```shell
#     sudo ln -sf /usr/bin/[주피터 파이썬 버전] /usr/bin/python
#     ```

# %%
# %%bash
#
# sudo ln -sf /usr/bin/python3.10 /usr/bin/python
# python --version
# Out:
# Python 3.12.3

# %% [markdown]
# - 라이브러리 설치

# %%
# !pip install torch==2.8.0 bitsandbytes==0.47.0 accelerate==1.10.1 peft==0.17.1 trl==0.22.2 triton==3.4.0 cut_cross_entropy==25.1.1 sentencepiece==0.2.1 protobuf==6.32.0 datasets==3.6.0 huggingface_hub==0.34.4 hf_transfer==0.1.9
# !{sys.executable} -m pip install --upgrade unsloth unsloth_zoo 
# !{sys.executable} -m pip --no-deps unsloth
# !pip install --upgrade git+https://github.com/ggerganov/llama.cpp
    
# !pip install transformers==4.55.4
# !pip install --no-deps trl==0.22.2
# Out:
# Requirement already satisfied: torch==2.8.0 in /usr/local/lib/python3.12/dist-packages (2.8.0+cu128)
# Collecting bitsandbytes==0.47.0
#   Downloading bitsandbytes-0.47.0-py3-none-manylinux_2_24_x86_64.whl.metadata (11 kB)
# Collecting accelerate==1.10.1
#   Downloading accelerate-1.10.1-py3-none-any.whl.metadata (19 kB)
# Collecting peft==0.17.1
#   Downloading peft-0.17.1-py3-none-any.whl.metadata (14 kB)
# Collecting trl==0.22.2
#   Downloading trl-0.22.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (3.4.0)
# Collecting cut_cross_entropy==25.1.1
#   Downloading cut_cross_entropy-25.1.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting sentencepiece==0.2.1
#   Downloading sentencepiece-0.2.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting protobuf==6.32.0
#   Downloading protobuf-6.32.0-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting datasets==3.6.0
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Collecting huggingface_hub==0.34.4
#   Downloading huggingface_hub-0.34.4-py3-none-any.whl.metadata (14 kB)
# Collecting hf_transfer==0.1.9
#   Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0) (1.13.1.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes==0.47.0) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate==1.10.1) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate==1.10.1) (7.1.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate==1.10.1) (6.0.3)
# Collecting safetensors>=0.4.3 (from accelerate==1.10.1)
#   Downloading safetensors-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting transformers (from peft==0.17.1)
#   Downloading transformers-4.57.0-py3-none-any.whl.metadata (41 kB)
# Collecting tqdm (from peft==0.17.1)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting pyarrow>=15.0.0 (from datasets==3.6.0)
#   Downloading pyarrow-21.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets==3.6.0)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting pandas (from datasets==3.6.0)
#   Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (2.32.5)
# Collecting xxhash (from datasets==3.6.0)
#   Downloading xxhash-3.6.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.17 (from datasets==3.6.0)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface_hub==0.34.4)
#   Downloading hf_xet-1.1.10-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.7 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0)
#   Downloading aiohttp-3.13.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (25.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0)
#   Downloading frozenlist-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0)
#   Downloading multidict-6.7.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0)
#   Downloading propcache-0.4.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0)
#   Downloading yarl-1.22.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (75 kB)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (3.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.6.0) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.6.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.6.0) (2025.10.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.8.0) (1.3.0)
# Collecting regex!=2019.12.17 (from transformers->peft==0.17.1)
#   Downloading regex-2025.9.18-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers->peft==0.17.1)
#   Downloading tokenizers-0.22.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.8.0) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==3.6.0) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->datasets==3.6.0)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->datasets==3.6.0)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==3.6.0) (1.16.0)
# Downloading bitsandbytes-0.47.0-py3-none-manylinux_2_24_x86_64.whl (61.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 MB 98.4 MB/s  0:00:006m0:00:0100:01
# Downloading accelerate-1.10.1-py3-none-any.whl (374 kB)
# Downloading peft-0.17.1-py3-none-any.whl (504 kB)
# Downloading trl-0.22.2-py3-none-any.whl (544 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 544.8/544.8 kB 5.1 MB/s  0:00:00
# Downloading cut_cross_entropy-25.1.1-py3-none-any.whl (22 kB)
# Downloading sentencepiece-0.2.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 20.8 MB/s  0:00:00
# Downloading protobuf-6.32.0-cp39-abi3-manylinux2014_x86_64.whl (322 kB)
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
# Downloading huggingface_hub-0.34.4-py3-none-any.whl (561 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.5/561.5 kB 5.8 MB/s  0:00:00
# Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 41.1 MB/s  0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading hf_xet-1.1.10-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 43.5 MB/s  0:00:00
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Downloading aiohttp-3.13.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 26.1 MB/s  0:00:00
# Downloading multidict-6.7.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (256 kB)
# Downloading yarl-1.22.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (377 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (242 kB)
# Downloading propcache-0.4.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (221 kB)
# Downloading pyarrow-21.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (42.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 95.8 MB/s  0:00:006m0:00:01
# Downloading safetensors-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (485 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading transformers-4.57.0-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 84.8 MB/s  0:00:00
# Downloading tokenizers-0.22.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 38.5 MB/s  0:00:00
# Downloading regex-2025.9.18-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (802 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.0/802.0 kB 9.0 MB/s  0:00:00
# Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 83.2 MB/s  0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading xxhash-3.6.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (193 kB)
# Installing collected packages: pytz, xxhash, tzdata, tqdm, sentencepiece, safetensors, regex, pyarrow, protobuf, propcache, multidict, hf-xet, hf_transfer, frozenlist, dill, aiohappyeyeballs, yarl, pandas, multiprocess, huggingface_hub, aiosignal, tokenizers, aiohttp, transformers, cut_cross_entropy, bitsandbytes, accelerate, peft, datasets, trl
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30/30 [trl]32m29/30 [trl]sets]e]s]ub]
# Successfully installed accelerate-1.10.1 aiohappyeyeballs-2.6.1 aiohttp-3.13.0 aiosignal-1.4.0 bitsandbytes-0.47.0 cut_cross_entropy-25.1.1 datasets-3.6.0 dill-0.3.8 frozenlist-1.8.0 hf-xet-1.1.10 hf_transfer-0.1.9 huggingface_hub-0.34.4 multidict-6.7.0 multiprocess-0.70.16 pandas-2.3.3 peft-0.17.1 propcache-0.4.1 protobuf-6.32.0 pyarrow-21.0.0 pytz-2025.2 regex-2025.9.18 safetensors-0.6.2 sentencepiece-0.2.1 tokenizers-0.22.1 tqdm-4.67.1 transformers-4.57.0 trl-0.22.2 tzdata-2025.2 xxhash-3.6.0 yarl-1.22.0
# Collecting unsloth
#   Downloading unsloth-2025.10.1-py3-none-any.whl.metadata (53 kB)
# Collecting unsloth_zoo
#   Downloading unsloth_zoo-2025.10.1-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: torch>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (2.8.0+cu128)
# Collecting xformers>=0.0.27.post2 (from unsloth)
#   Downloading xformers-0.0.32.post2-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.47.0)
# Requirement already satisfied: triton>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from unsloth) (25.0)
# Collecting tyro (from unsloth)
#   Downloading tyro-0.9.33-py3-none-any.whl.metadata (12 kB)
# Collecting transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,<=4.56.2,>=4.51.3 (from unsloth)
#   Downloading transformers-4.56.2-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: datasets!=4.0.*,!=4.1.0,>=3.4.1 in /usr/local/lib/python3.12/dist-packages (from unsloth) (3.6.0)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.2.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from unsloth) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from unsloth) (7.1.0)
# Collecting wheel>=0.42.0 (from unsloth)
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from unsloth) (2.1.2)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.12/dist-packages (from unsloth) (1.10.1)
# Requirement already satisfied: trl!=0.15.0,!=0.19.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.23.0,>=0.7.9 in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.22.2)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.17.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from unsloth) (6.32.0)
# Requirement already satisfied: huggingface_hub>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.34.4)
# Requirement already satisfied: hf_transfer in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.1.9)
# Collecting diffusers (from unsloth)
#   Downloading diffusers-0.35.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.23.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,<=4.56.2,>=4.51.3->unsloth) (3.20.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,<=4.56.2,>=4.51.3->unsloth) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,<=4.56.2,>=4.51.3->unsloth) (2025.9.18)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,<=4.56.2,>=4.51.3->unsloth) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,<=4.56.2,>=4.51.3->unsloth) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,<=4.56.2,>=4.51.3->unsloth) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->unsloth) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->unsloth) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->unsloth) (1.1.10)
# Collecting torchao (from unsloth_zoo)
#   Downloading torchao-0.13.0-1-cp39-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: cut_cross_entropy in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo) (25.1.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo) (11.0.0)
# Collecting msgspec (from unsloth_zoo)
#   Downloading msgspec-0.19.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth) (21.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth) (2.3.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth) (3.13.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth) (3.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,<=4.56.2,>=4.51.3->unsloth) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,<=4.56.2,>=4.51.3->unsloth) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,<=4.56.2,>=4.51.3->unsloth) (2025.10.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (1.13.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.4.0->unsloth) (1.3.0)
# Collecting importlib_metadata (from diffusers->unsloth)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting zipp>=3.20 (from importlib_metadata->diffusers->unsloth)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.4.0->unsloth) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth) (1.16.0)
# Collecting docstring-parser>=0.15 (from tyro->unsloth)
#   Downloading docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=11.1.0 (from tyro->unsloth)
#   Downloading rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Collecting shtab>=1.5.6 (from tyro->unsloth)
#   Downloading shtab-1.7.2-py3-none-any.whl.metadata (7.4 kB)
# Collecting typeguard>=4.0.0 (from tyro->unsloth)
#   Downloading typeguard-4.4.4-py3-none-any.whl.metadata (3.3 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=11.1.0->tyro->unsloth)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1.0->tyro->unsloth) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro->unsloth)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading unsloth-2025.10.1-py3-none-any.whl (317 kB)
# Downloading transformers-4.56.2-py3-none-any.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 91.3 MB/s  0:00:00
# Downloading unsloth_zoo-2025.10.1-py3-none-any.whl (257 kB)
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
# Downloading xformers-0.0.32.post2-cp39-abi3-manylinux_2_28_x86_64.whl (117.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 MB 170.1 MB/s  0:00:000:00:0100:01
# Downloading diffusers-0.35.1-py3-none-any.whl (4.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 50.8 MB/s  0:00:00
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading msgspec-0.19.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
# Downloading torchao-0.13.0-1-cp39-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 63.5 MB/s  0:00:00
# Downloading tyro-0.9.33-py3-none-any.whl (132 kB)
# Downloading docstring_parser-0.17.0-py3-none-any.whl (36 kB)
# Downloading rich-14.2.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading shtab-1.7.2-py3-none-any.whl (14 kB)
# Downloading typeguard-4.4.4-py3-none-any.whl (34 kB)
# Installing collected packages: torchao, zipp, wheel, typeguard, shtab, msgspec, mdurl, docstring-parser, markdown-it-py, importlib_metadata, rich, diffusers, xformers, tyro, transformers, unsloth_zoo, unsloth
#   Attempting uninstall: transformers━━╸━━━━━━━━━ 13/17 [tyro]ers]]metadata]
#     Found existing installation: transformers 4.57.0m━━━━━━━━━ 13/17 [tyro]
#     Uninstalling transformers-4.57.0:━━━╸━━━━━━━ 14/17 [transformers]
#       Successfully uninstalled transformers-4.57.0━━━━━━━ 14/17 [transformers]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17/17 [unsloth]6/17 [unsloth]zoo]]
# Successfully installed diffusers-0.35.1 docstring-parser-0.17.0 importlib_metadata-8.7.0 markdown-it-py-4.0.0 mdurl-0.1.2 msgspec-0.19.0 rich-14.2.0 shtab-1.7.2 torchao-0.13.0 transformers-4.56.2 typeguard-4.4.4 tyro-0.9.33 unsloth-2025.10.1 unsloth_zoo-2025.10.1 wheel-0.45.1 xformers-0.0.32.post2 zipp-3.23.0
#
# Usage:
#   /usr/local/bin/python -m pip <command> [options]
#
# no such option: --no-deps
# Collecting git+https://github.com/ggerganov/llama.cpp
#   Cloning https://github.com/ggerganov/llama.cpp to /tmp/pip-req-build-r6z0b9ao
#   Running command git clone --filter=blob:none --quiet https://github.com/ggerganov/llama.cpp /tmp/pip-req-build-r6z0b9ao
#   Resolved https://github.com/ggerganov/llama.cpp to commit f9bc66c3ebcfddb5f09e4b21253623caeb8e414a
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Processing /tmp/pip-req-build-r6z0b9ao/gguf-py (from llama-cpp-scripts==0.0.0)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting numpy<2.0.0,>=1.25.0 (from llama-cpp-scripts==0.0.0)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting protobuf<5.0.0,>=4.21.0 (from llama-cpp-scripts==0.0.0)
#   Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting sentencepiece<=0.2.0,>=0.1.98 (from llama-cpp-scripts==0.0.0)
#   Downloading sentencepiece-0.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: torch<3.0.0,>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from llama-cpp-scripts==0.0.0) (2.8.0+cu128)
# Requirement already satisfied: transformers<5.0.0,>=4.35.2 in /usr/local/lib/python3.12/dist-packages (from llama-cpp-scripts==0.0.0) (4.56.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from gguf@ file:///tmp/pip-req-build-r6z0b9ao/gguf-py->llama-cpp-scripts==0.0.0) (6.0.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from gguf@ file:///tmp/pip-req-build-r6z0b9ao/gguf-py->llama-cpp-scripts==0.0.0) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.0->llama-cpp-scripts==0.0.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.0->llama-cpp-scripts==0.0.0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.0->llama-cpp-scripts==0.0.0) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.0->llama-cpp-scripts==0.0.0) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.0->llama-cpp-scripts==0.0.0) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.0->llama-cpp-scripts==0.0.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.0->llama-cpp-scripts==0.0.0) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.0->llama-cpp-scripts==0.0.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.0->llama-cpp-scripts==0.0.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.0->llama-cpp-scripts==0.0.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.0->llama-cpp-scripts==0.0.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.0->llama-cpp-scripts==0.0.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.0->llama-cpp-scripts==0.0.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.0->llama-cpp-scripts==0.0.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.0->llama-cpp-scripts==0.0.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.0->llama-cpp-scripts==0.0.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.0->llama-cpp-scripts==0.0.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.0->llama-cpp-scripts==0.0.0) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.0->llama-cpp-scripts==0.0.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.0->llama-cpp-scripts==0.0.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.0->llama-cpp-scripts==0.0.0) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.0->llama-cpp-scripts==0.0.0) (3.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.35.2->llama-cpp-scripts==0.0.0) (0.34.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.35.2->llama-cpp-scripts==0.0.0) (25.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.35.2->llama-cpp-scripts==0.0.0) (2025.9.18)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.35.2->llama-cpp-scripts==0.0.0) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.35.2->llama-cpp-scripts==0.0.0) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.35.2->llama-cpp-scripts==0.0.0) (0.6.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers<5.0.0,>=4.35.2->llama-cpp-scripts==0.0.0) (1.1.10)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0.0,>=2.2.0->llama-cpp-scripts==0.0.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0.0,>=2.2.0->llama-cpp-scripts==0.0.0) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<5.0.0,>=4.35.2->llama-cpp-scripts==0.0.0) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<5.0.0,>=4.35.2->llama-cpp-scripts==0.0.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<5.0.0,>=4.35.2->llama-cpp-scripts==0.0.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<5.0.0,>=4.35.2->llama-cpp-scripts==0.0.0) (2025.10.5)
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 44.2 MB/s  0:00:00m0:00:01:00:01
# Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Downloading sentencepiece-0.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 37.8 MB/s  0:00:00
# Building wheels for collected packages: llama-cpp-scripts, gguf
#   Building wheel for llama-cpp-scripts (pyproject.toml) ... done
#   Created wheel for llama-cpp-scripts: filename=llama_cpp_scripts-0.0.0-py3-none-any.whl size=131226 sha256=8bb8bc176a2f3993ea0fc0f43d7ab12f368e9d3f965b2dd89202123cde187b27
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w51vp0y_/wheels/b7/cf/5d/778c8de857b73f070c95ed879c24447257d9d357571316a933
#   Building wheel for gguf (pyproject.toml) ... done
#   Created wheel for gguf: filename=gguf-0.17.1-py3-none-any.whl size=105772 sha256=f8186aa98e1d6030b5b99cc11d36aa69ecde9e8fbe7554ced8b0b3918d251fa5
#   Stored in directory: /workspace/.cache/pip/wheels/3d/0d/61/23d2bc61cc8906ba5b36e0fe3635bf383824b2db1760f2b3fe
# Successfully built llama-cpp-scripts gguf
# Installing collected packages: sentencepiece, protobuf, numpy, gguf, llama-cpp-scripts
#   Attempting uninstall: sentencepiece
#     Found existing installation: sentencepiece 0.2.1
#     Uninstalling sentencepiece-0.2.1:
#       Successfully uninstalled sentencepiece-0.2.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.32.0
#     Uninstalling protobuf-6.32.0:
#       Successfully uninstalled protobuf-6.32.0
#   Attempting uninstall: numpym━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/5 [protobuf]
#     Found existing installation: numpy 2.1.2━━━━━━━━━━━━━━━━━━ 1/5 [protobuf]
#     Uninstalling numpy-2.1.2:0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/5 [protobuf]
#       Successfully uninstalled numpy-2.1.2m━━━━━━━━━━━━━━━━━━━━━━━ 2/5 [numpy]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [llama-cpp-scripts]llama-cpp-scripts]
# Successfully installed gguf-0.17.1 llama-cpp-scripts-0.0.0 numpy-1.26.4 protobuf-4.25.8 sentencepiece-0.2.0
# Collecting transformers==4.55.4
#   Downloading transformers-4.55.4-py3-none-any.whl.metadata (41 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.55.4) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.55.4) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.55.4) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.55.4) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.55.4) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.55.4) (2025.9.18)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.55.4) (2.32.5)
# Collecting tokenizers<0.22,>=0.21 (from transformers==4.55.4)
#   Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers==4.55.4) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.55.4) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.55.4) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.55.4) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.55.4) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.55.4) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.55.4) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.55.4) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.55.4) (2025.10.5)
# Downloading transformers-4.55.4-py3-none-any.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 69.1 MB/s  0:00:00
# Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 36.3 MB/s  0:00:00
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.1
#     Uninstalling tokenizers-0.22.1:
#       Successfully uninstalled tokenizers-0.22.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.56.2
#     Uninstalling transformers-4.56.2:╺━━━━━━━━━━━━━━━━━━━ 1/2 [transformers]
#       Successfully uninstalled transformers-4.56.2━━━━━━━━━━━━ 1/2 [transformers]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [transformers] [transformers]
# Successfully installed tokenizers-0.21.4 transformers-4.55.4
# Requirement already satisfied: trl==0.22.2 in /usr/local/lib/python3.12/dist-packages (0.22.2)

# %% [markdown]
# ## [Load Model](https://huggingface.co/unsloth)

# %%
from unsloth import FastModel
import torch

fourbit_models = [
    # 4bit dynamic quants for superior accuracy and low memory use
    "unsloth/gemma-3-1b-it-unsloth-bnb-4bit",
    "unsloth/gemma-3-4b-it-unsloth-bnb-4bit",
    "unsloth/gemma-3-12b-it-unsloth-bnb-4bit",
    "unsloth/gemma-3-27b-it-unsloth-bnb-4bit",

    # Other popular models!
    "unsloth/Llama-3.1-8B",
    "unsloth/Llama-3.2-3B",
    "unsloth/Llama-3.3-70B",
    "unsloth/mistral-7b-instruct-v0.3",
    "unsloth/Phi-4",
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastModel.from_pretrained(
    model_name = "unsloth/gemma-3-1b-it",
    max_seq_length = 8184, # Choose any for long context!
    load_in_4bit = True,  # 4 bit quantization to reduce memory
    load_in_8bit = False, # [NEW!] A bit more accurate, uses 2x memory
    full_finetuning = False, # [NEW!] We have full finetuning now!
    # token = "hf_...", # use one if using gated models
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.10.1: Fast Gemma3 patching. Transformers: 4.55.4.
#    \\   /|    NVIDIA RTX A5000. Num GPUs = 1. Max memory: 23.573 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu128. CUDA: 8.6. CUDA Toolkit: 12.8. Triton: 3.4.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.32.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: Gemma3 does not support SDPA - switching to fast eager.
# model.safetensors:   0%|          | 0.00/1.00G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/233 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/670 [00:00<?, ?B/s]

# %% [markdown]
# ## PEFT : LoRA

# %%
model = FastModel.get_peft_model(
    model,
    finetune_vision_layers     = False, # Turn off for just text!
    finetune_language_layers   = True,  # Should leave on!
    finetune_attention_modules = True,  # Attention good for GRPO
    finetune_mlp_modules       = True,  # SHould leave on always!
    r = 16,           # 0보다 큰 어떤 숫자도 선택 가능! 8, 16, 32, 64, 128이 권장됩니다.
    lora_alpha = 16,  # Recommended alpha == r at least
    lora_dropout = 0,
    bias = "none",   # 바이어스를 지원합니다.
    random_state = 3407
)
# Out:
# Unsloth: Making `model.base_model.model.model` require gradients

# %% [markdown]
# ## datasets

# %%
from datasets import load_dataset

dataset = load_dataset("csv", data_files="df_train.csv", split="train")
dataset
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset({
#     features: ['user_input', 'reference', 'reference_video_url'],
#     num_rows: 50
# })

# %%
# EOS_TOKEN은 문장의 끝을 나타내는 토큰입니다. 이 토큰을 추가해야 합니다.
EOS_TOKEN = tokenizer.eos_token

# AlpacaPrompt를 사용하여 지시사항을 포맷팅하는 함수입니다.
alpaca_prompt = """Below is an instruction that describes a task. Write a response that appropriately completes the request.

### Instruction:
{}

### Response:
{}"""

# 주어진 예시들을 포맷팅하는 함수입니다.
def formatting_prompts_func(examples):
    instructions = examples["user_input"]  # 지시사항을 가져옵니다.
    outputs = examples["reference"]  # 출력값을 가져옵니다.
    texts = []  # 포맷팅된 텍스트를 저장할 리스트입니다.
    for instruction, output in zip(instructions, outputs):
        # EOS_TOKEN을 추가해야 합니다. 그렇지 않으면 생성이 무한히 진행될 수 있습니다.
        text = alpaca_prompt.format(instruction, output) + EOS_TOKEN
        texts.append(text)
    return {
        "text": texts,  # 포맷팅된 텍스트를 반환합니다.
    }

# 데이터셋에 formatting_prompts_func 함수를 적용합니다. 배치 처리를 활성화합니다.
dataset = dataset.map(
    formatting_prompts_func,
    batched=True,
)
# Out:
# Map:   0%|          | 0/50 [00:00<?, ? examples/s]

# %%
dataset[0]
# Out:
# {'user_input': '갑상선 기능 항진증이 어린이에게 미치는 영향은 무엇인가요?',
#  'reference': '갑상선 기능 항진증은 어린이가 체력을 소모시키는 병으로, 이로 인해 땀을 많이 흘릴 수 있습니다. 그러나 땀을 많이 흘린다고 해서 반드시 심각한 문제가 있는 것은 아니며, 다른 이상이 없는 경우에는 대개 체계적인 경우로 생각할 수 있습니다.',
#  'reference_video_url': 'https://www.youtube.com/watch?v=8GwNlF44ntY&list=PLC6Msm1YCNw-NJBk4ajBkTeS2rJULiT1b',
#  'text': 'Below is an instruction that describes a task. Write a response that appropriately completes the request.\n\n### Instruction:\n갑상선 기능 항진증이 어린이에게 미치는 영향은 무엇인가요?\n\n### Response:\n갑상선 기능 항진증은 어린이가 체력을 소모시키는 병으로, 이로 인해 땀을 많이 흘릴 수 있습니다. 그러나 땀을 많이 흘린다고 해서 반드시 심각한 문제가 있는 것은 아니며, 다른 이상이 없는 경우에는 대개 체계적인 경우로 생각할 수 있습니다.<end_of_turn>'}

# %%
from trl import SFTTrainer, SFTConfig

tokenizer.padding_side = "right"  # 토크나이저의 패딩을 오른쪽으로 설정합니다.

# SFTTrainer를 사용하여 모델 학습 설정
trainer = SFTTrainer(
    model=model,  # 학습할 모델
    tokenizer=tokenizer,  # 토크나이저
    train_dataset=dataset,  # 학습 데이터셋
    eval_dataset=dataset,# 테디노트에서 추가된 eval dataset
    dataset_text_field="text",  # 데이터셋에서 텍스트 필드의 이름
    dataset_num_proc=2,  # 데이터 처리에 사용할 프로세스 수
    packing=False,  # 짧은 시퀀스에 대한 학습 속도를 5배 빠르게 할 수 있음
    args=SFTConfig(
        max_seq_length=7994,  # 최대 시퀀스 길이
        per_device_train_batch_size=2,  # 각 디바이스당 훈련 배치 크기
        gradient_accumulation_steps=4,  # 그래디언트 누적 단계
        warmup_steps=5,  # 웜업 스텝 수
        num_train_epochs=10,  # 훈련 에폭 수
        max_steps=100,  # 최대 스텝 수 # 공식문서에는 60
        logging_steps=1,  # logging 스텝 수
        learning_rate=2e-4,  # 학습률
        fp16=not torch.cuda.is_bf16_supported(),  # fp16 사용 여부, bf16이 지원되지 않는 경우에만 사용
        bf16=torch.cuda.is_bf16_supported(),  # bf16 사용 여부, bf16이 지원되는 경우에만 사용
        optim="adamw_8bit",  # 최적화 알고리즘
        weight_decay=0.01,  # 가중치 감소
        lr_scheduler_type="cosine",  # 학습률 스케줄러 유형 # 공식은 linear
        seed=123,  # 랜덤 시드 # 공식은 3407
        output_dir="outputs",  # 출력 디렉토리
    ),
)
# Out:
# num_proc must be <= 50. Reducing num_proc to 50 for dataset of size 50.
# Unsloth: Tokenizing ["text"] (num_proc=50):   0%|          | 0/50 [00:00<?, ? examples/s]
# num_proc must be <= 50. Reducing num_proc to 50 for dataset of size 50.

# %% [markdown]
# ## Train

# %%
# @title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = NVIDIA RTX A5000. Max memory = 23.573 GB.
# 0.996 GB of memory reserved.

# %%
# @title Training model
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 50 | Num Epochs = 15 | Total steps = 100
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 13,045,760 of 1,012,931,712 (1.29% trained)
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100/100 02:02, Epoch 14/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.110200</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.483400</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.974700</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.759600</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.693400</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.762700</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.681600</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.218900</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.122600</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.076100</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>2.104900</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.719900</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.967000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.817300</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.601400</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.721600</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.548100</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.533200</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.515500</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.686700</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.717100</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.466600</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.342600</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.266300</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.390600</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.207100</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.266300</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.273400</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.057300</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.877300</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.045700</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.107700</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.158200</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.026600</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.174500</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.887100</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.963700</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.843200</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.736000</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.804600</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.814900</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.734700</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.624600</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.663500</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.583700</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.732900</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.573900</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.553400</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.756700</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.404600</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.526200</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.443200</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.369900</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.505600</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.433200</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.466300</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.366400</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.361400</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.347500</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.272600</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.258200</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.330300</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.299900</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.293300</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.275800</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.186600</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.207400</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.196000</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.252700</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.164600</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.161200</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.192000</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.168000</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.122500</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.158700</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.177600</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.227100</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.169700</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>0.155600</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.119800</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.087700</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>0.131100</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>0.139800</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.092000</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.097700</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.117800</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>0.101000</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.124700</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.105800</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.115800</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>0.164600</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>0.120100</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>0.127800</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>0.112600</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.104100</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.095700</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>0.080100</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>0.054800</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.087400</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.101700</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# @title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory / max_memory * 100, 3)
lora_percentage = round(used_memory_for_lora / max_memory * 100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(
    f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training."
)
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# 158.7474 seconds used for training.
# 2.65 minutes used for training.
# Peak reserved memory = 1.641 GB.
# Peak reserved memory for training = 0.645 GB.
# Peak reserved memory % of max memory = 6.961 %.
# Peak reserved memory for training % of max memory = 2.736 %.

# %% [markdown]
# ## Inference

# %%
from unsloth.chat_templates import get_chat_template
tokenizer = get_chat_template(
    tokenizer,
    chat_template = "gemma-3",
)

# %%
messages = [{
    "role": "user",
    "content": "허니 햄버거 병이란 무엇인가요?",
}]

text = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt = True, # Must add for generation
    tokenize=False,               # 반드시 False로 해야 문자열 반환됨
)

from transformers import TextStreamer

_ = model.generate(
    **tokenizer([text], return_tensors = "pt").to("cuda"),
    max_new_tokens = 64, # Increase for longer outputs!
    # Recommended Gemma-3 settings!
    temperature = 1.0, top_p = 0.95, top_k = 64,
    streamer = TextStreamer(tokenizer, skip_prompt = True),
)
# Out:
# 허니 햄버거 병은 음식물과 세균이 감염되는 상태를 말하며, 특히 치아가 출생 시부터 제대로 발달하지 않으면 발생할 수 있습니다.
#
# 좀 더 자세히 설명해 드릴게요.
#
# ### 허니 햄버거 병이란 무엇인가요?

# %% [markdown]
# ## save model

# %% [markdown]
# ### VLLM을 위한 float4 저장

# %%
base_model = "model" # 병합을 수행할 베이스 모델

# %%
model.save_pretrained_merged(
    base_model,
    tokenizer
)
# Out:
# config.json:   0%|          | 0.00/902 [00:00<?, ?B/s]
# Found HuggingFace hub cache directory: /workspace/.cache/huggingface/hub
# Checking cache directory for required files...
# Cache check failed: model.safetensors not found in local cache.
# Not all required files found in cache. Will proceed with downloading.
# Unsloth: Preparing safetensor model files:   0%|          | 0/1 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/2.00G [00:00<?, ?B/s]
# Unsloth: Preparing safetensor model files: 100%|██████████| 1/1 [00:07<00:00,  7.71s/it]
# Unsloth: Merging weights into 16bit: 100%|██████████| 1/1 [00:08<00:00,  8.86s/it]
# Unsloth: Merge process complete. Saved to `/workspace/model`

# %% [markdown]
# ### GGUF 변환

# %%
# Quantization 방식 설정
quantization_method = "q8_0"  # "f16" "q8_0" "q4_k_m" "q5_k_m"

# %% [markdown]
# model.save_pretrained_gguf(
#     base_model, # 사전학습 모델이 저장될 폴더명
#     tokenizer=tokenizer,
#     quantization_type=quantization_method,
# )

# %% [markdown]
# ## HuggingFace 업로드

# %% [markdown]
# ### [HuggingFace API Key](https://huggingface.co/settings/tokens)

# %%
import os

os.environ["HF_TOKEN"] = "hf_"

# %%
from huggingface_hub import login

login(
    token=os.environ["HF_TOKEN"]
)
print("로그인 성공")
# Out:
# 로그인 성공

# %% [markdown]
# ### 기존 레포지토리 삭제

# %%
from huggingface_hub import HfApi

# API 인스턴스 생성
api = HfApi()

# 사용자의 Hugging Face 계정 ID
huggingface_id = "good593"
new_repo_id = f"{huggingface_id}/gemma3-finetune-diseases-gguf"

try:
    
    # 지정된 저장소를 완전히 삭제
    api.delete_repo(repo_id=new_repo_id)
    print("삭제가 완료되었습니다.")
except Exception as e:
    # 삭제할 저장소가 존재하지 않거나 권한이 없는 경우
    print("삭제할 대상이 없습니다.")
# Out:
# 삭제가 완료되었습니다.

# %% [markdown]
# ### 수동 업로드

# %%
try:
    
    # 지정된 저장소를 생성
    api.create_repo(repo_id=new_repo_id)
    print("생성이 완료되었습니다.")
except Exception as e:
    # 삭제할 저장소가 존재하지 않거나 권한이 없는 경우
    print("생성할 대상이 없습니다.")
# Out:
# 생성이 완료되었습니다.

# %%
# 생성된 저장소에 파일 업로드 
api.upload_file(
    path_or_fileobj="./model.Q8_0.gguf",
    path_in_repo="model.Q8_0.gguf",
    repo_id=new_repo_id,
    repo_type="model",
    # token = "hf_"
)
# Out:
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#   ./model.Q8_0.gguf                     :   3%|2         | 27.6MB / 1.07GB
# CommitInfo(commit_url='https://huggingface.co/good593/gemma3-finetune-diseases-gguf/commit/f44eca04bae0e8d2af55054fbbab7f664e97b06f', commit_message='Upload model.Q8_0.gguf with huggingface_hub', commit_description='', oid='f44eca04bae0e8d2af55054fbbab7f664e97b06f', pr_url=None, repo_url=RepoUrl('https://huggingface.co/good593/gemma3-finetune-diseases-gguf', endpoint='https://huggingface.co', repo_type='model', repo_id='good593/gemma3-finetune-diseases-gguf'), pr_revision=None, pr_num=None)

# %% [markdown]
# ### [hugging face 확인](https://huggingface.co/good593/gemma3-finetune-gguf)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Ollama 적용

# %% [markdown]
# ### gguf 파일 다운로드

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Modelfile 생성

# %% [markdown]
# ```Modelfile
# FROM model.Q8_0.gguf
#
# TEMPLATE """{{- if .System }}
# <s>{{ .System }}</s>
# {{- end }}
# <s>Human:
# {{ .Prompt }}</s>
# <s>Assistant:
# """
#
# SYSTEM """A chat between a curious user and an artificial intelligence assistant. The assistant gives helpful, detailed, and polite answers to the user's questions."""
#
# PARAMETER temperature 0
# PARAMETER num_predict 3000
# PARAMETER num_ctx 4096
# PARAMETER stop <s>
# PARAMETER stop </s>
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Ollama Model 생성
# ```shell
# # ollama create [올라마 모델명]:[테그] -f Modelfile
# ollama create fine_tuning_gemma3:1b -f Modelfile
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ```shell
# # 설치된 모든 모델 조회
# ollama list
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Ollama Model 테스트

# %% [markdown]
# - 학습하기 전 gemma3:1b

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 학습한 fine_tuning_gemma3:1b

# %% [markdown]
# ![image.png](attachment:image.png)
