# %% [markdown]
# # Multi Agents - 코드 리뷰 시스템 (중급)
#
# ## 개요
# LangGraph를 활용하여 여러 에이전트가 병렬로 실행되고 결과를 집계하는 코드 리뷰 시스템을 구현합니다.
#
# ## 구성
# 1. **코드 분석 에이전트**: 코드 구조와 로직 파악
# 2. **버그 검사 에이전트**: 잠재적 버그와 오류 찾기
# 3. **스타일 검사 에이전트**: 코딩 컨벤션 및 스타일 확인
# 4. **성능 분석 에이전트**: 성능 이슈 및 최적화 제안
# 5. **통합 리포트 에이전트**: 모든 리뷰 결과 종합
#
# ## 학습 목표
# - 병렬 실행 (parallel execution): 여러 에이전트 동시 실행
# - 결과 집계 (aggregation): 각 에이전트 결과를 모아서 처리
# - 독립적 작동: 각 에이전트가 서로 의존하지 않고 실행

# %% [markdown]
# ## 1. 환경 설정 및 라이브러리 임포트

# %%
import os
from typing import TypedDict, List, Annotated
from operator import add
from langgraph.graph import StateGraph, END
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage

# %% [markdown]
# ### API 키 설정
# - [OpenAI API 키](https://platform.openai.com/api-keys)

# %%
import os

# API 키 설정
os.environ["OPENAI_API_KEY"] = "sk-proj-"

# API 키 확인
openai_key = os.getenv("OPENAI_API_KEY")

if openai_key:
    print("OpenAI API 키가 설정되었습니다. (GPT 모델 사용)")
else:
    print("OpenAI API 키가 없습니다.")
# Out:
# OpenAI API 키가 설정되었습니다. (GPT 모델 사용)

# %% [markdown]
# ### LLM 초기화

# %%
# LLM 초기화
llm = ChatOpenAI(model="gpt-5-nano")

# %% [markdown]
# ## 2. 상태 정의 (State Management)
#
# 병렬 실행을 위한 상태 구조를 정의합니다. `Annotated`와 `add` 연산자를 사용하여 각 에이전트의 결과를 리스트에 집계합니다.

# %%
class ReviewState(TypedDict):
    """
    코드 리뷰 시스템의 상태를 정의하는 클래스
    
    Attributes:
        code: 리뷰할 코드
        reviews: 각 에이전트의 리뷰 결과 리스트 (자동 집계)
        final_report: 통합 리포트
    """
    code: str
    reviews: Annotated[List[str], add]  # add 연산자로 자동 집계
    final_report: str

print("상태 구조가 정의되었습니다.")
print("reviews 필드는 Annotated[List[str], add]로 정의되어 자동으로 결과를 집계합니다.")
# Out:
# 상태 구조가 정의되었습니다.
# reviews 필드는 Annotated[List[str], add]로 정의되어 자동으로 결과를 집계합니다.

# %% [markdown]
# ## 3. 병렬 실행 에이전트 정의
#
# 각 에이전트는 독립적으로 코드를 분석하고, 결과를 `reviews` 리스트에 추가합니다.

# %% [markdown]
# ### 3.1 코드 분석 에이전트

# %%
def code_analysis_agent(state: ReviewState) -> dict:
    """
    코드의 구조와 로직을 분석하는 에이전트
    """
    code = state["code"]
    
    messages = [
        SystemMessage(content="""
            당신은 코드 구조 분석 전문가입니다.
            다음 관점에서 코드를 분석하세요:
            - 전체적인 구조와 설계 패턴
            - 함수/클래스의 역할과 책임
            - 코드의 가독성과 유지보수성
            - 모듈화 수준

            간결하고 명확하게 분석 결과를 제공하세요."""),
        HumanMessage(content=f"다음 코드를 분석하세요:\n\n{code}")
    ]
    
    response = llm.invoke(messages)
    review = f"[코드 구조 분석]\n{response.content}"
    
    print("[코드 분석 에이전트] 분석 완료")
    
    return {
        "reviews": [review]  # 리스트로 반환하여 자동 집계
    }

# %% [markdown]
# ### 3.2 버그 검사 에이전트

# %%
def bug_detection_agent(state: ReviewState) -> dict:
    """
    잠재적 버그와 오류를 찾는 에이전트
    """
    code = state["code"]
    
    messages = [
        SystemMessage(content="""
            당신은 버그 탐지 전문가입니다.
            다음 관점에서 코드를 검사하세요:
            - 논리적 오류 가능성
            - 예외 처리 누락
            - Null/Undefined 참조 위험
            - 경계 조건 처리
            - 리소스 누수 가능성

            발견된 문제와 해결 방안을 제시하세요."""),
        HumanMessage(content=f"다음 코드에서 버그를 찾으세요:\n\n{code}")
    ]
    
    response = llm.invoke(messages)
    review = f"[버그 검사]\n{response.content}"
    
    print("[버그 검사 에이전트] 검사 완료")
    
    return {
        "reviews": [review]
    }

# %% [markdown]
# ### 3.3 스타일 검사 에이전트

# %%
def style_check_agent(state: ReviewState) -> dict:
    """
    코딩 컨벤션과 스타일을 검사하는 에이전트
    """
    code = state["code"]
    
    messages = [
        SystemMessage(content="""
            당신은 코딩 스타일 전문가입니다.
            다음 관점에서 코드를 검사하세요:
            - 네이밍 컨벤션 (변수, 함수, 클래스명)
            - 코드 포맷팅 (들여쓰기, 줄바꿈)
            - 주석의 적절성
            - 코드 일관성
            - 베스트 프랙티스 준수 여부

            개선 사항을 구체적으로 제안하세요."""),
        HumanMessage(content=f"다음 코드의 스타일을 검사하세요:\n\n{code}")
    ]
    
    response = llm.invoke(messages)
    review = f"[스타일 검사]\n{response.content}"
    
    print("[스타일 검사 에이전트] 검사 완료")
    
    return {
        "reviews": [review]
    }

# %% [markdown]
# ### 3.4 성능 분석 에이전트

# %%
def performance_analysis_agent(state: ReviewState) -> dict:
    """
    성능 이슈를 분석하고 최적화 방안을 제안하는 에이전트
    """
    code = state["code"]
    
    messages = [
        SystemMessage(content="""
            당신은 성능 최적화 전문가입니다.
            다음 관점에서 코드를 분석하세요:
            - 시간 복잡도와 공간 복잡도
            - 불필요한 연산이나 중복 코드
            - 메모리 사용 효율성
            - 알고리즘 최적화 가능성
            - 병목 지점

            구체적인 최적화 방안을 제시하세요."""),
        HumanMessage(content=f"다음 코드의 성능을 분석하세요:\n\n{code}")
    ]
    
    response = llm.invoke(messages)
    review = f"[성능 분석]\n{response.content}"
    
    print("[성능 분석 에이전트] 분석 완료")
    
    return {
        "reviews": [review]
    }

# %% [markdown]
# ## 4. 결과 집계 에이전트
#
# 모든 병렬 에이전트의 결과를 받아 통합 리포트를 생성합니다.

# %%
def aggregation_agent(state: ReviewState) -> dict:
    """
    모든 리뷰 결과를 종합하여 최종 리포트를 생성하는 에이전트
    """
    code = state["code"]
    reviews = state["reviews"]
    
    # 모든 리뷰 결과를 하나의 문자열로 결합
    all_reviews = "\n\n".join(reviews)
    
    messages = [
        SystemMessage(content="""
            당신은 시니어 코드 리뷰어입니다.
            여러 전문가들의 리뷰 결과를 받았습니다. 이를 종합하여:
            1. 주요 발견 사항 요약
            2. 우선순위별 개선 사항 정리
            3. 전체적인 코드 품질 평가
            4. 구체적인 액션 아이템 제시

            명확하고 실행 가능한 최종 리포트를 작성하세요."""),
        HumanMessage(content=f"다음은 각 전문가들의 리뷰입니다:\n\n{all_reviews}\n\n이를 종합하여 최종 리포트를 작성하세요.")
    ]
    
    response = llm.invoke(messages)
    final_report = response.content
    
    print("[통합 리포트 에이전트] 최종 리포트 생성 완료")
    
    return {
        "final_report": final_report
    }

# %% [markdown]
# ## 5. 그래프 구성 (병렬 실행)
#
# 여러 에이전트가 동시에 실행되도록 그래프를 구성합니다.
#
# ### 그래프 구조
# ```
#                     시작
#                      |
#                      v
#          +-----------+-----------+
#          |           |           |
#          v           v           v
#   코드 분석    버그 검사    스타일 검사
#          |           |           |
#          +-----+-----+-----------+
#                |           |
#                v           v
#           성능 분석   (병렬 실행)
#                |
#                v
#           통합 리포트
#                |
#                v
#              종료
# ```

# %%
# StateGraph 생성
workflow = StateGraph(ReviewState)

# 병렬 실행될 노드들 추가
workflow.add_node("code_analysis", code_analysis_agent)
workflow.add_node("bug_detection", bug_detection_agent)
workflow.add_node("style_check", style_check_agent)
workflow.add_node("performance_analysis", performance_analysis_agent)

# 결과 집계 노드 추가
workflow.add_node("aggregation", aggregation_agent)

# 시작점 설정 - 4개의 에이전트로 동시 분기
workflow.set_entry_point("code_analysis")
workflow.set_entry_point("bug_detection")
workflow.set_entry_point("style_check")
workflow.set_entry_point("performance_analysis")

# 모든 병렬 에이전트에서 집계 에이전트로 연결
workflow.add_edge("code_analysis", "aggregation")
workflow.add_edge("bug_detection", "aggregation")
workflow.add_edge("style_check", "aggregation")
workflow.add_edge("performance_analysis", "aggregation")

# 집계 에이전트에서 종료
workflow.add_edge("aggregation", END)

# 그래프 컴파일
app = workflow.compile()

print("병렬 실행 그래프가 성공적으로 구성되었습니다!")
print("4개의 에이전트가 동시에 실행되고, 결과가 자동으로 집계됩니다.")
# Out:
# 병렬 실행 그래프가 성공적으로 구성되었습니다!
# 4개의 에이전트가 동시에 실행되고, 결과가 자동으로 집계됩니다.

# %% [markdown]
# ## 6. 그래프 시각화 (선택사항)

# %%
try:
    from IPython.display import Image, display
    display(Image(app.get_graph().draw_mermaid_png()))
except Exception as e:
    print(f"그래프 시각화를 위해서는 graphviz가 필요합니다: {e}")
    print("텍스트로 그래프 구조를 확인하세요:")
    print(app.get_graph())

# %% [markdown]
# ## 7. 테스트 예제
#
# 실제 코드를 리뷰하는 예제입니다.

# %% [markdown]
# ### 7.1 테스트 코드 준비

# %%
# 리뷰할 샘플 코드 (의도적으로 개선 여지가 있는 코드)
sample_code = """
def find_duplicates(list):
    result = []
    for i in range(len(list)):
        for j in range(len(list)):
            if i != j and list[i] == list[j]:
                if list[i] not in result:
                    result.append(list[i])
    return result

def calculate_average(numbers):
    sum = 0
    for n in numbers:
        sum = sum + n
    avg = sum / len(numbers)
    return avg

class userManager:
    def __init__(self):
        self.users = []
    
    def add_user(self, name, age):
        self.users.append({'name': name, 'age': age})
    
    def get_user(self, name):
        for user in self.users:
            if user['name'] == name:
                return user
        return None
"""

print("샘플 코드가 준비되었습니다.")
# Out:
# 샘플 코드가 준비되었습니다.

# %% [markdown]
# ### 7.2 코드 리뷰 실행

# %%
print("=" * 80)
print("코드 리뷰 시작")
print("=" * 80)

# 초기 상태 생성
initial_state = {
    "code": sample_code,
    "reviews": [],
    "final_report": ""
}

# 그래프 실행 (병렬 실행)
result = app.invoke(initial_state)

print("\n" + "=" * 80)
print("코드 리뷰 완료!")
print("=" * 80)
# Out:
# ================================================================================
# 코드 리뷰 시작
# ================================================================================
# Failed to multipart ingest runs: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# [코드 분석 에이전트] 분석 완료
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# [성능 분석 에이전트] 분석 완료
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# [버그 검사 에이전트] 검사 완료
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# [스타일 검사 에이전트] 검사 완료
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# [통합 리포트 에이전트] 최종 리포트 생성 완료
#
# ================================================================================
# 코드 리뷰 완료!
# ================================================================================
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %% [markdown]
# ### 7.3 개별 리뷰 결과 확인

# %%
print("\n" + "=" * 80)
print("개별 에이전트 리뷰 결과")
print("=" * 80)

for i, review in enumerate(result["reviews"], 1):
    print(f"\n리뷰 {i}:")
    print("-" * 80)
    print(review)
    print()
# Out:
# ================================================================================
# 개별 에이전트 리뷰 결과
# ================================================================================
#
# 리뷰 1:
# --------------------------------------------------------------------------------
# [버그 검사]
# 다음 코드에서 발견되는 버그/취약점과 개선 방안을 정리합니다.
#
# 1) find_duplicates(list)
# - 문제점
#   - 매개변수 이름이 Python의 내장 타입 이름인 list와 같은 이름으로 되어 있어 가독성과 혼동의 위험이 있습니다.
#   - 입력 검증 부재로 None 또는 비 리스트형 입력에 대해 명확한 예외를 주지 않습니다.
#   - 이중 루프(O(n^2))로 비효율적이며, 필요 시 더 빠른 구현이 가능합니다.
#   - 경계 조건: 빈 리스트를 입력하면 빈 결과를 반환하지만, 명시적인 예외 처리나 경계 체크를 추가해 의도를 명확히 할 수 있습니다.
# - 개선 제안
#   - 매개변수명을 items 또는 values로 변경하고 입력을 검증합니다.
#   - 시간 복잡도를 줄이고, 원하면 원소의 등장 여부를 유지하는 방식으로 중복 원소를 한 번만 반환하도록 구현합니다.
#   - 예시 구현(A: 순서를 보존하지 않는 간단 버전, B: 순서를 보존하면서 중복을 하나씩만 반환하는 버전)
#
# A 버전(간단하고 성능 개선 가능):
# - 코드:
# def find_duplicates(values):
#     if values is None:
#         raise ValueError("values must not be None")
#     seen = set()
#     duplicates = set()
#     for v in values:
#         if v in seen:
#             duplicates.add(v)
#         else:
#             seen.add(v)
#     return list(duplicates)
#
# B 버전(순서를 보존하며 중복을 처음 등장한 순서대로 수집):
# - 코드:
# def find_duplicates(values):
#     if values is None:
#         raise ValueError("values must not be None")
#     seen = set()
#     duplicates = []
#     duplicates_set = set()
#     for v in values:
#         if v in seen:
#             if v not in duplicates_set:
#                 duplicates.append(v)
#                 duplicates_set.add(v)
#         else:
#             seen.add(v)
#     return duplicates
#
# 참고: 원래 코드는 i, j를 전부 비교하여 중복 여부를 판단하고, 이미 결과에 존재하는지 확인합니다. 이 로직은 올바르게 동작하나, 비효율적이고 매개변수 이름이 혼란스러우므로 위와 같이 개선하는 것이 좋습니다.
#
# 2) calculate_average(numbers)
# - 문제점
#   - 변수 이름 sum이 Python의 내장 함수 sum을 그림자(오버라이드)합니다. 이는 코드의 다른 부분에서 내장 sum을 사용할 때 의도치 않은 버그를 야기할 수 있습니다.
#   - 입력이 비어 있는 경우 0으로 나누게 되어 ZeroDivisionError가 발생합니다.
#   - 입력 검증 부재로 None 또는 비수치형 요소가 들어오면 예외가 불가피하게 발생합니다.
# - 개선 제안
#   - sum이라는 이름으로 변수를 만들지 말고, 내장 sum을 사용하거나 로컬 변수명을 total로 변경합니다.
#   - 숫자 리스트가 비어 있지 않도록 검증하고, None 체크를 추가합니다.
#   - 가능하면 내장 sum을 활용하되, 안전한 타입 체크를 병행하는 것이 좋습니다.
#
# 개선된 예시:
# - 코드:
# def calculate_average(numbers):
#     if numbers is None:
#         raise ValueError("numbers must not be None")
#     if len(numbers) == 0:
#         raise ValueError("numbers must not be empty")
#     total = 0
#     for n in numbers:
#         total += n
#     return total / len(numbers)
#
# (또는 간단히: return sum(numbers) / len(numbers) 를 사용하되, 앞의 None/빈 리스트 체크를 유지)
#
# 3) class userManager
# - 문제점
#   - 클래스 이름이 PEP8에 어긋나며(UserManager 권장) 가독성 저하.
#   - add_user에서 입력 검증 부재로 잘못된 데이터가 들어올 수 있습니다. 예: name이 None이거나 age가 음수인 경우.
#   - get_user에서 특정 키가 누락된 사전이 있을 경우 KeyError가 발생하지 않지만, 현재는 user['name']로 바로 접근해 KeyError 위험이 있습니다.
#   - 다중 동일 이름 사용 시 첫 번째 매치를 반환하는 동작은 의도에 따라 다를 수 있습니다.
# - 개선 제안
#   - 클래스 이름을 UserManager로 변경(Pep8 준수).
#   - 입력 검증 추가. name은 문자열, age는 양의 정수로 확인.
#   - get_user에서 키 접근 시 안전하게 get으로 조회.
#   - 필요 시 여러 사용자를 다루는 메서드 추가(예: get_all_users, remove_user 등).
#
# 개선된 예시:
# - 코드:
# class UserManager:
#     def __init__(self):
#         self.users = []
#
#     def add_user(self, name, age):
#         if name is None or age is None:
#             raise ValueError("name과 age는 None일 수 없습니다")
#         if not isinstance(name, str) or not isinstance(age, int) or age < 0:
#             raise ValueError("Invalid user data: name must be str, age must be non-negative int")
#         self.users.append({'name': name, 'age': age})
#
#     def get_user(self, name):
#         for user in self.users:
#             if user.get('name') == name:
#                 return user
#         return None
#
# 참고 및 추가 권고
# - Null/Undefined 참조 위험
#   - 각 함수에 입력 유효성 검사(ValueError 등) 추가로 None값으로 인한 예외를 명시적으로 처리했습니다.
#   - get_user에서 dict 접근은 get으로 안전하게 처리하는 것이 좋습니다.
# - 경계 조건 처리
#   - calculate_average는 비어 있는 입력에 대해 명시적으로 예외를 발생시키도록 했습니다.
#   - find_duplicates는 None 입력에 대해 명시적으로 처리했습니다.
# - 리소스 누수 가능성
#   - 이 코드들에서 리소스(파일 핸들링, 네트워크 소켓 등)가 열리고 닫히는 부분이 없으므로 리소스 누수 문제는 없으나, 확장 시 리소스 관리에 주의해야 합니다.
# - 예외 처리 누락
#   - 모든 함수에서 입력 값에 대한 기본적인 예외 처리를 추가하는 것을 권장합니다. 특히 외부 입력에 의존하는 함수일수록 구체적인 예외를 던지도록 하는 것이 좋습니다.
# - 스타일 및 견고성
#   - 변수명에서 내장 타입 이름의 사용을 피하고, 가능하면 타입 힌트를 추가하는 것이 유지보수에 도움이 됩니다.
#   - 필요 시 유닛 테스트를 추가해 경계조건(빈 입력, None, 잘못된 타입 등)을 자동으로 검증하도록 권장합니다.
#
# 요약
# - find_duplicates: 매개변수 이름의 충돌 방지, None 입력에 대한 명시적 검사, 비효율적 이중 루프 개선 권장.
# - calculate_average: sum 이름 그림자 회피, None/빈 입력에 대한 검증, ZeroDivision 방지.
# - UserManager: 클래스 이름 PEP8 수정, 입력 검증 강화, get_user의 안전한 딕셔너리 접근 사용.
#
# 원하시면 위의 개선을 반영한 전체 통합 코드 버전도 제공합니다.
#
#
# 리뷰 2:
# --------------------------------------------------------------------------------
# [코드 구조 분석]
# 다음 코드를 구조·설계 관점에서 분석합니다.
#
# - 전체적인 구조와 설계 패턴
#   - 간단한 순수 함수 두 개와 한 개의 관리 클래스가 한 파일에 나란히 존재합니다.
#   - 모듈화나 계층구조보다는 즉시 실행 가능한 임시 유틸리티와 메모리상 데이터 저장소를 묶은 형태입니다.
#   - 의도는 작고 자립적인 도구들을 제공하는 스타일이지만, 실무에서는 하나의 파일에 좁은 책임의 컴포넌트가 모여 있어 확장성과 재사용성이 떨어집니다.
#
# - 함수/클래스의 역할과 책임
#   - find_duplicates(list)
#     - 역할: 주어진 리스트에서 중복된 값을 찾아 중복 여부가 한 번 이상 등장하는 값들을 모아 반환합니다.
#     - 책임: 중복 탐지(가로채기 없이 모든 쌍 비교) 및 결과 중복 제거.
#     - 특성: 이중 루프(O(n^2))로 구현되어 데이터 크기가 커질수록 비효율적입니다. 결과는 중복 값들만 하나씩 모아 리스트로 반환합니다.
#   - calculate_average(numbers)
#     - 역할: 숫자들이 들어 있는 컬렉션의 평균을 계산합니다.
#     - 책임: 합계 계산 및 평균 산출.
#     - 특성: sum 변수 이름이 파이썬 내장 함수 sum를 가리게 되는 이름 충돌 위험이 있고, 빈 입력에 대해 0으로 나누는 문제가 발생할 수 있습니다.
#   - class userManager
#     - 역할: 이름-나이 쌍으로 이루어진 사용자를 관리하는 간단한 저장소 역할.
#     - 책임: add_user로 사용자를 저장하고, get_user로 이름으로 검색해 해당 사용자를 반환합니다.
#     - 특성: 내부 저장소가 리스트이고, 이름으로 검색할 때 선형 탐색으로 처리합니다. 클래스 이름은 PEP8의 대문자 카멜케이스 관례와 다르게 소문자+대문자 혼용으로 작성되어 있습니다.
#
# - 가독성과 유지보수성
#   - 네이밍 및 스타일
#     - 파라미터 이름 list는 파이썬 빌트인 리스트 타입과 이름이 겹쳐 혼동의 여지가 있습니다.
#     - sum 변수는 파이썬의 내장 함수 이름과 동일하여 가독성과 잠재적 버그 위험을 높입니다.
#     - 클래스 이름은 UserManager 같은 PEP8 표준에 맞춘 스타일이 더 적합합니다.
#   - 문서화와 타입 힌트의 부재
#     - 함수/메서드에 docstring이나 타입 힌트가 없어 사용 의도와 입력/출력 타입 파악이 어렵습니다.
#   - 에러처리와 입력 검증의 부재
#     - calculate_average는 빈 입력 시 ZeroDivisionError가 발생할 수 있습니다. 잘못된 입력(비수치형 등)에 대한 방어도 없습니다.
#     - get_user은 이름으로 찾지 못하면 None을 반환하지만, 호출 측에서 이를 어떻게 처리할지에 대한 가이드가 부족합니다.
#   - 확장성 및 유지보수성
#     - 현재 구현은 기능 단위로 재사용이 어렵고, 기능이 늘어나면 코드 중복이 증가할 가능성이 큽니다.
#     - 데이터 저장 방식이 리스트이므로 대용량 데이터나 고유 키로의 빠른 조회에 비효율적입니다.
#
# - 모듈화 수준
#   - 모든 로직이 한 파일 내부에 존재합니다. 작은 규모의 스크립트나 예제용으로는 괜찮을 수 있지만, 실무의 서비스 레이어나 비즈니스 로직으로 확장하기엔 모듈 경계가 모호하고 재사용성이 떨어집니다.
#   - 데이터 모델(User)을 별도 모듈이나 데이터 클래스로 분리하면 유지보수가 쉬워질 여지가 있습니다.
#
# - 구체적인 개선 포인트
#   - find_duplicates 개선
#     - 내장 함수나 컬렉션 도구를 활용해 O(n)~O(n log n) 수준으로 개선 가능.
#     - 예: 중복 여부를 카운트하고, 등장 횟수가 2회 이상인 값만 추출하는 방식으로 구현하거나, 순서를 보존하면서 중복값만 추출하도록 구현.
#     - 파라미터 이름을 list에서 lst나 values로 바꿔 빌트인 이름 충돌 회피.
#   - calculate_average 개선
#     - 내장 sum 사용 및 빈 리스트에 대한 예외 처리 추가.
#     - 타입 힌트 추가 (numbers: Iterable[float|int]) 및 반환 타입(float) 명시.
#     - 예: if not numbers: raise ValueError("numbers는 비어 있을 수 없습니다") 또는 0 반환 등의 정책 명시.
#   - userManager 개선
#     - 클래스 이름을 UserManager로 변경(Pep8 준수).
#     - User 데이터를 dataclass로 분리하면 가독성 상승 및 확장에 유리.
#     - 저장소를 리스트가 아닌 dict로 바꿔 이름으로의 조회를 O(1)로 만들기.
#     - 이름 중복 처리, 유효성 검사(나이의 비음수 여부 등) 추가.
#     - 추가 기능 예: remove_user, update_user, list_users, __repr__/__str__ 구현.
#     - 가능하다면 저장소를 인터페이스로 추상화하고, 실제 저장소(메모리/DB)를 교체하기 쉬운 구조로 설계.
#
# - 짧은 예시 제안(개선 방향 요약)
#   - find_duplicates 예시 방향
#     - 중복 값 집합을 이용하고 순서는 유지 필요 시 OrderedDict나 dict.fromkeys 조합으로 구현.
#   - calculate_average 예시 방향
#     - 합계 = sum(numbers); 평균 = 합계 / len(numbers) (빈 입력 검증 포함)
#   - User 모델 및 저장소 예시 방향
#     - @dataclass
#       class User:
#         name: str
#         age: int
#     - class UserManager:
#         def __init__(self):
#             self._users: Dict[str, User] = {}
#         def add_user(self, name: str, age: int) -> None:
#             if name in self._users:
#                 raise ValueError("이미 존재하는 사용자 이름입니다.")
#             self._users[name] = User(name, age)
#         def get_user(self, name: str) -> Optional[User]:
#             return self._users.get(name)
#
# - 간단한 테스트 아이디어
#   - find_duplicates: [1, 2, 2, 3, 4, 4] -> [2, 4] 같은 결과가 나오는지 확인
#   - calculate_average: [1, 2, 3, 4] -> 2.5 확인, [] 입력 시 예외 여부 확인
#   - UserManager: add_user와 get_user 동작 확인(추가/조회), 중복 추가 시 예외 발생 여부 확인
#
# 요약
# - 현재 코드는 소규모 유틸리티와 간단한 in-memory 저장소를 한 파일에 담은 형태로, 구조적으로는 단순하지만 가독성, 확장성, 유지보수성 측면에서 개선 여지가 큽니다.
# - 각 구성요소의 책임을 명확히 하고, 파이썬 표준 스타일(Pep8)과 현대적인 기술스택(데이터 클래스, 예외 처리, 타입 힌트, 더 efficient 데이터 구조)로 리팩트하면 재사용성과 확장성이 크게 향상됩니다.
#
#
# 리뷰 3:
# --------------------------------------------------------------------------------
# [성능 분석]
# 다음 코드를 관찰하면 가장 큰 성능 이슈는 find_duplicates 함수의 중첩 루프와 리스트를 결과로 사용할 때의 불필요한 중복 검사입니다. 나머지 부분은 상대적으로 양호하지만 일부 코드 관리 측면에서 개선 여지가 있습니다.
#
# 1) find_duplicates(list)
#
# - 현황
#   - 시간 복잡도: 이중 루프가 list의 모든 쌍(i, j)을 탐색합니다. 최악의 경우 약 O(n^2) 실행이고, 내부에서 결과 리스트에 이미 있는 값을 또 검사하는 “list 내의 in 검사”가 추가로 O(k)(결과 길이)로 작동합니다. 따라서 최악의 경우 O(n^3)에 이를 수 있습니다.
#   - 공간 복잡도: 결과를 저장하는 데 O(D) 공간. 중복이 아닌 값은 저장되지 않으므로 D는 중복으로 간주되는 고유 값의 수로, 최악이면 O(n)까지 갈 수 있습니다.
#   - 메모리/속도 문제 요약: 입력 리스트가 커질수록 비효율이 커지며, 중복 확인 로직이 비효율적입니다.
#   - 코드 품질 이슈: 매개변수 이름이 내장 타입 이름(list)을 덮어쓰고 있음. 또한 불필요한 중복 검사와 비교가 반복됩니다.
#
# - 최적화 방안
#   - 한 번의 스캔으로 중복을 추출하는 방식으로 변경합니다. set을 사용해 본 순간 이미 등장한 값을 빠르게 확인하고, 중복으로 처음 나타난 값만 결과에 추가합니다.
#   - 예시 코드(순서를 유지하거나 유지하지 않는 두 가지 버전):
#     - 순서를 유지하고 중복을 한 번만 기록:
#       이름을 data나 arr로 바꾸고 아래처럼 구현
#       자료구조: seen(집합), duplicates(목록), duplicates_seen(중복으로 이미 추가됨 여부를 위한 집합)
#       - 시간: O(n), 공간: O(n)
#     - 순서 무시하고 간단히 집합으로 중복 추출:
#       seen = set(), duplicates = set(); for x in arr: if x in seen: duplicates.add(x); else: seen.add(x); return list(duplicates)
#   - 권장 코드 예시(순서를 유지하는 버전):
#     - 참고: 중복값이 처음 등장한 순서대로 결과에 담깁니다.
#       로직은 크게 3개의 집합/리스트를 사용합니다: seen, duplicates, duplicates_seen
#       def find_duplicates(data):
#           seen = set()
#           duplicates = []
#           duplicates_seen = set()
#           for x in data:
#               if x in seen:
#                   if x not in duplicates_seen:
#                       duplicates.append(x)
#                       duplicates_seen.add(x)
#               else:
#                   seen.add(x)
#           return duplicates
#
#   - 이 방식의 장점: 시간 복잡도 O(n), 공간 복잡도 O(n), 내부 in 연산이 집합으로 상수 시간에 가능해져 전체 성능이 크게 개선됩니다. 또한 리스트 내 중복 검사(in result) 대신 집합으로 신속히 판단합니다.
#   - 추가 개선 포인트:
#     - 매개변수 이름을 list에서 data나 arr로 바꿔 파이썬 내장 이름과 충돌 피하기.
#     - 필요한 경우 타입 힌트 추가.
#
# 2) calculate_average(numbers)
#
# - 현황
#   - 시간 복잡도: O(n) (numbers를 한 번 순회하며 합산)
#   - 공간 복잡도: O(1) (입력 외의 상수 공간만 사용)
#   - 문제점
#     - sum 변수를 로컬 변수로 사용하면서 파이썬의 내장 sum 이름을 가리는 부작용이 있습니다.
#     - numbers가 비어 있을 때 나눗셈으로 ZeroDivisionError 발생 가능.
#     - 반복문 대신 파이썬의 내장 sum을 활용하면 코드가 간결하고 빠릅니다.
#
# - 최적화 방안
#   - sum 내장함수를 사용하고 변수 이름 충돌 방지.
#   - 비어 있는 입력에 대한 안전 처리 혹은 적절한 예외 처리.
#   - 권장 코드 예시:
#     def calculate_average(numbers):
#         if not numbers:
#             raise ValueError("numbers must not be empty")
#         return sum(numbers) / len(numbers)
#
#   - 대안으로 statistics.mean(numbers)를 사용할 수도 있습니다(가독성 상승).
#
# 3) class userManager
#
# - 현황
#   - add_user: 리스트에 딕셔너리 형태로 추가(O(1) 시간)
#   - get_user: 리스트를 순회하며 이름으로 비교하는 선형 탐색(O(n) 시간)
#   - 메모리: 각 사용자를 작은 딕셔너리로 저장하므로 메모리 오버헤드가 큼. 대규모 데이터일 때 비효율적일 수 있음.
#
# - 최적화 방안
#   - 데이터 구조를 바꿔 조회를 O(1)으로 만들기:
#     - 이름을 키로 하는 사전(dict)을 사용하면 get_user이 O(1) 평균으로 빨라집니다.
#     - 간단한 버전:
#       class UserManager:
#           def __init__(self):
#               self.users = {}  # name -> {'name': name, 'age': age}
#           def add_user(self, name, age):
#               self.users[name] = {'name': name, 'age': age}
#           def get_user(self, name):
#               return self.users.get(name)
#     - 만약 동일한 이름의 사용자가 여러 명일 수 있다면:
#       - self.users를 name -> list[User] 형태로 구성하고, add_user에서 이름으로 리스트에 추가, get_user에서 리스트를 반환하거나 필요한 형태로 가공
#     - 데이터 모델을 개선할 경우, 데이터 클래스(dataclass)나 NamedTuple을 사용해 메모리 사용과 코드를 더 명확하게 만들 수 있습니다.
#       예: using dataclass
#       from dataclasses import dataclass
#       @dataclass
#       class User:
#           name: str
#           age: int
#       class UserManager:
#           def __init__(self):
#               self.users: dict[str, User] = {}
#           def add_user(self, name, age):
#               self.users[name] = User(name, age)
#           def get_user(self, name):
#               return self.users.get(name)
#
#   - 주의점
#     - 이름이 중복될 수 있는 경우 로직이 달라져야 합니다. 중복 허용 여부에 따라 저장 형태를 조정해야 합니다.
#     - 메모리 최적화를 원하면 필요 필드만 담거나, dataclass의 __slots__를 활용하는 등 객체 구조를 조정할 수 있습니다.
#
# 4) 전체적으로 권고하는 종합 전략
#
# - 코드 품질/안정성
#   - 변수 이름 개선: list, sum 같은 이름은 피하고, 데이터 용도에 맞는 이름 사용.
#   - 입력에 대한 예외 처리나 경계 조건 검사 추가.
#   - 가능하면 타입 힌트 추가로 가독성과 정적 분석 이점 확보.
#
# - 알고리즘/성능 측면의 우선 순위
#   - 최우선: find_duplicates의 중복 제거 로직을 O(n)으로 바꿔야 합니다. 현재 구조가 가장 큰 병목이므로 첫 번째 개선 대상으로 추천.
#   - 두 번째: userManager의 조회를 O(1)로 바꾸면 실제 사용성 향상에 큰 차이가 납니다. 데이터를 자주 조회하는 시나리오가 있다면 도입 권장.
#   - calculate_average는 already efficient이므로 내장 함수를 사용하고 예외 처리를 추가하는 선에서 충분합니다.
#
# - 마이크로 최적화/추가 개선
#   - 필요 시 프로파일링 도구를 사용해 실제로 시간이 많이 소요되는 부분이 어떤지 확인한 후 최적화 대상 집중.
#   - 대규모 데이터의 경우 메모리 프로파일링도 고려해 불필요한 객체 생성 최소화.
#
# - 예시 비교 요약
#   - find_duplicates: 기존 O(n^2)~O(n^3) → 추천 개선 O(n) 시간, O(n) 공간
#   - calculate_average: 개선 전 O(n) 시간, O(1) 공간 + 내장 sum 사용으로 간결성 증가 + 빈 입력 처리 추가
#   - userManager: 기존 O(n) 조회 → O(1) 조회로 개선 가능, 메모리 트레이드오프 존재(두 구조 유지 시), 데이터 모델을 dataclass로 정리하면 가독성·메모리 관리에 이점
#
# 원하신다면 위의 최적화 코드를 실제 코드 파일에 바로 적용할 수 있도록 전체 예제 파일 형태로 제공해 드리겠습니다. 또한, 성능 측정 방법(timeit, cProfile 등)과 함께 구체적인 벤치마크 예시도 추가해 드릴 수 있습니다.
#
#
# 리뷰 4:
# --------------------------------------------------------------------------------
# [스타일 검사]
# 다음 코드를 스타일 관점에서 점검하고, 개선점을 구체적으로 제안합니다.
#
# 전반 요약
# - 네이밍 컨벤션이 일관되지 않고, 파이썬의 기본 컨벤션과 충돌하는 부분이 있습니다.
# - 변수 이름이 파이썬의 예약어나 빌트인 이름과 중복(shadowing)되어 혼란을 야기합니다.
# - 주석/문서화가 부족합니다. 함수/클래스에 대한 간단한 설명이 필요합니다.
# - 코드 포맷팅이 다소 어긋나는 부분이 있습니다(두 개의 공백 라인 권고를 지키지 않음, 클래스 명명 규칙 등).
# - 베스트 프랙티스에 어긋나는 부분이 다수 있습니다(빌트인 이름 사용, 불필요한 이중 루프, 더 나은 자료구조 사용 가능성 등).
#
# 상세 평가 및 구체적 개선 제안
#
# 1) 네이밍 컨벤션
# - 문제점
#   - 매개변수로 사용된 list는 파이썬의 빌트인 타입과 이름이 겹쳐 혼동을 일으킵니다.
#   - 클래스 이름은 userManager처럼 소문자+대문자 혼합으로 되어 있어 파이썬의 클래스 명명 규칙(CamelCase)과 다릅니다.
#   - 변수 이름 sum은 파이썬의 빌트인 sum와 충돌합니다.
# - 개선 제안
#   - 파라미터/변수명은 빌트인 이름을 피하고 snake_case를 따르며, 리스트를 나타내는 경우도 items나 elements 등으로 명명합니다.
#   - 클래스명은 UserManager처럼 CamelCase로 작성합니다.
#   - 가능하면 데이터 구조를 나타내는 이름을 사용합니다.
#
# 2) 코드 포맷팅
# - 문제점
#   - top-level 정의 사이에 필요한 두 줄 공백이 지켜지지 않는 경우가 있습니다(PEP 8).
#   - 문자열, 연산자 간의 공백 규칙은 대체로 지켜져 있지만, 전체 스타일 가이드를 준수하는 것이 좋습니다.
# - 개선 제안
#   - 두 개의 빈 줄로 기능/클래스 간 구분을 명확히 합니다.
#   - 전체 파일에서 들여쓰기 4칸(또는 탭 이슈를 피하기 위해 4칸 일관성 유지)을 유지합니다.
#
# 3) 주석 및 문서화
# - 문제점
#   - 함수와 클래스에 대한 설명(docstring)이 전혀 없습니다.
# - 개선 제안
#   - 각 함수/메서드에 간단한 docstring을 추가합니다. 예: 매개변수, 반환값, 예외 상황에 대한 설명.
#
# 4) 코드 일관성
# - 문제점
#   - 함수의 동작 방식이 파이썬의 idiom에 맞춘 구현 대신 이중 루프 등 비효율적 방법을 사용합니다.
#   - 빌트인 이름을 피하지 않아 혼동 가능성이 있습니다.
# - 개선 제안
#   - 일관된 네이밍 규칙과 파이썬ic한 구현으로 리팩토링합니다.
#   - 데이터 표현에 사전(dict) 대신 dataclass를 활용해 타입 안정성과 읽기 쉬움을 높일 수 있습니다.
#
# 5) 베스트 프랙티스 준수 여부
# - 문제점
#   - 이중 for 루프로 중복 탐지를 수행하는 것은 비효율적이며, 단순히 중복 여부를 찾는 목적에 어울리지 않습니다.
#   - sum이라는 빌트인 이름을 변수로 사용하는 등 빌트인 네임충돌 위험.
#   - 예외 처리나 입력 유효성 검사 부족.
# - 개선 제안
#   - 파이썬의 내장 함수(sum)를 활용하고, 빌트인 이름은 피합니다.
#   - 입력이 비어 있을 때의 평균 계산 처리를 명시적으로 다룹니다.
#   - 필요하면 타입 힌트와 예외를 추가해 사용성을 높입니다.
#
# 구체적 개선 예시
#
# 1) find_duplicates 개선안
# - 목표: 중복된 값을 중복 한 번만 반환하고, 빌트인 이름을 피하며, 파라미터 명을 명확히 합니다.
# - 권장 구현 1(효율적이고 읽기 쉬운 버전, 원본 순서 유지 방법 포함):
#   - 이 버전은 아이템의 등장 여부를 추적하고, 중복으로 발견된 아이템만 결과에 추가합니다.
#   - 예시:
#     - def find_duplicates(items):
#         seen = set()
#         duplicates = []
#         for item in items:
#             if item in seen:
#                 if item not in duplicates:
#                     duplicates.append(item)
#             else:
#                 seen.add(item)
#         return duplicates
#
# - 권장 구현 2(카운트 기반, 원소의 중복 여부를 간단하게 얻고 싶을 때):
#   - 예시:
#     - from collections import Counter
#       def find_duplicates(items):
#           counts = Counter(items)
#           return [item for item, c in counts.items() if c > 1]
#
# 2) calculate_average 개선안
# - 문제점: sum이라는 빌트인 이름 사용, 비어 있는 숫자 컬렉션 처리 부재.
# - 개선 예시:
#   - def calculate_average(numbers):
#       if not numbers:
#           raise ValueError("numbers must not be empty")
#       return sum(numbers) / len(numbers)
#
# - 타입 힌트 및 예외 처리 추가 예시:
#   - from typing import Sequence
#     def calculate_average(numbers: Sequence[float] | Sequence[int]) -> float:
#         if len(numbers) == 0:
#             raise ValueError("numbers must not be empty")
#         return sum(numbers) / len(numbers)
#
# 3) UserManager 개선안
# - 문제점: 클래스 명이 규칙에 맞지 않으며, 사용자 표현이 사전(dict)으로 구현되어 있습니다.
# - 개선 예시(데이터 클래스 도입, 타입 힌트, 네이밍 규칙 적용):
#   - from dataclasses import dataclass
#     from typing import List, Optional
#
#     @dataclass
#     class User:
#         name: str
#         age: int
#
#     class UserManager:
#         def __init__(self) -> None:
#             self.users: List[User] = []
#
#         def add_user(self, name: str, age: int) -> None:
#             self.users.append(User(name=name, age=age))
#
#         def get_user(self, name: str) -> Optional[User]:
#             for user in self.users:
#                 if user.name == name:
#                     return user
#             return None
#
# - 이 접근은 타입 안정성과 확장성(필드 추가 등)에 더 유리합니다. 또한 클래스명도 UserManager로 통일됩니다.
#
# 추가적으로 권고하는 일반 규칙
# - 네이밍 컨벤션:
#   - 함수/메서드: snake_case
#   - 변수: snake_case
#   - 클래스: CamelCase
# - 주석/문서화:
#   - 모든 공개 함수/메서드에 docstring을 추가합니다.
#   - 복잡한 로직은 주석으로 의도와 구현 방식을 설명합니다.
# - 입력 유효성 검사:
#   - calculate_average처럼 비어 있는 입력에 대한 예외를 처리합니다.
#   - add_user에서 성별이나 이메일 등 확장이 필요한 경우 기본 타입 검사를 추가합니다.
# - 코드 품질 도구의 활용:
#   - PEP 8 검사(예: flake8) 및 타입 검사(MyPy) 도입을 고려합니다.
# - 테스트:
#   - 각 함수별 단위 테스트를 작성해 스타일과 동작을 함께 검증합니다.
#
# 요약
# - 현재 코드는 네이밍 일관성 부족, 빌트인 이름 충돌, 주석 부재, 비효율적 구현 등의 문제를 갖고 있습니다.
# - 개선 방향은: 네이밍 규칙을 통일하고, 빌트인 이름 피하기, 문서화 추가, 파이썬ic한 구현으로 리팩토링, 타입 힌트 도입, 두 개의 빈 줄로 상위 정의 간 구분 등 PEP 8 준수를 강화하는 방향으로 진행하는 것이 좋습니다.
# - 제시된 개선안을 참고해 각 부분을 점진적으로 리팩토링하면 더 읽기 쉽고 유지보수가 쉬운 코드가 됩니다.

# %% [markdown]
# ### 7.4 통합 리포트 확인

# %%
print("\n" + "=" * 80)
print("최종 통합 리포트")
print("=" * 80)
print()
print(result["final_report"])
print()
print("=" * 80)
# Out:
# ================================================================================
# 최종 통합 리포트
# ================================================================================
#
# 다음은 제공된 전문가 리뷰를 종합한 최종 코드 품질 리포트입니다. 목적은 현재 구조의 문제를 명확히 파악하고, 실행 가능한 개선 로드맷을 제시하는 데 있습니다.
#
# 1) 주요 발견 사항 요약
# - 구조/설계
#   - 한 파일에 소규모 유틸리티와 간단한 저장소가 같이 있어 모듈화와 재사용성이 떨어짐.
#   - 데이터 모델과 저장소의 경계가 모호해 확장성 및 테스트 용이성이 저하됨.
# - find_duplicates의 문제점 및 개선 필요성
#   - 매개변수 이름이 내장 타입 이름(list)과 중복되어 가독성 저하 및 혼동 위험 있음.
#   - None 또는 비 리스트형 입력에 대한 입력 검증 부재.
#   - 이중 루프 기반 구현으로 비효율적이며, 최악의 경우 O(n^3) 수준의 비용도 야기 가능.
#   - 순서를 보존해야 하는지 여부에 따라 구현 방식이 다르고, 중복 값을 한 번만 반환하는 방식으로의 개선이 필요.
# - calculate_average의 문제점 및 개선 필요성
#   - sum이라는 로컬 변수 이름이 파이썬의 내장 sum을 그림자(오버라이드)함.
#   - 입력이 비어 있으면 0으로 나누는 ZeroDivisionError 가능성 존재.
#   - None/비수치형 요소에 대한 입력 검증이 미흡.
# - class userManager의 문제점 및 개선 필요성
#   - 클래스 이름이 파이썬 스타일(Pep8)과 다르게 작성되어 가독성 저하.
#   - 입력 검증 부재: name이 None이거나 age가 음수인 경우 등 잘못된 데이터 수용 가능성.
#   - get_user에서 키 접근 시 KeyError 위험이 있으며, 전체적으로 검색이 선형 탐색으로 비효율적임.
#   - 다중 동일 이름 처리 정책이 불명확하고, 변경 가능성 높은 요구사항에 대응하기 어렵다.
# - 스타일/문서화
#   - docstring, 타입 힌트 부재로 의도 파악 및 정적 분석의 이점이 거의 없음.
#   - 네이밍 컨벤션 혼재, 빌트인 이름 충돌 위험, 중복 검사 로직의 비효율성 등 스타일 규칙 위반 다수.
# - 테스트 부재
#   - 단위 테스트 부재로 경계 조건(빈 입력, None, 잘못된 타입)에 대한 회귀 테스트가 부족.
#
# 2) 우선순위별 개선 사항 정리
# 최우선 개선(높은 영향, 큰 이익)
# - find_duplicates의 전면적 개선
#   - 목표: O(n) 시간 복잡도와 안정적 동작으로, None 입력 처리 및 이름 충돌 제거.
#   - 구현 방향: 순서를 보존하든 보존하지 않든 요구사항에 맞춰 적절한 데이터 구조 선택.
#   - 예시 방향
#     - 순서를 유지하면서 중복을 한 번만 반환: seen, duplicates, duplicates_seen를 활용한 단일 패스 구현.
#     - 순서를 무시하고 중복만 모으기: seen와 duplicates를 이용한 간단한 버전.
# - calculate_average의 안정성 강화
#   - 목표: None/빈 입력 처리, 내장 sum의 안전한 사용, 변수 이름 충돌 방지.
#   - 구현 방향: 내장 sum 활용, 빈 입력에 대한 예외 처리 또는 정책 명시.
# - UserManager의 기초 리팩토링 시작
#   - 목표: 클래스명(Pep8), 입력 검증 강화, get_user의 안전한 조회 방식 도입.
#   - 구현 방향: 이름과 연령에 대한 검증, get_user에서 None 반환 시점 명확화, 가능하면 데이터 모델을 dataclass로 분리.
#
# 중간 개선(중간 효과, 합리적 변화)
# - find_duplicates의 안정성 강화와 타입 힌트 추가
#   - 함수 시그니처에 타입 힌트 도입, None 체크에 대한 명시적 예외 처리.
# - calculate_average에 대한 타입 힌트 및 간결성 보강
#   - 타입 힌트 추가, 예외 메시지 명확화.
# - UserManager의 네이밍/문서화 보강
#   - 클래스명 변경(Pep8에 맞춘 CamelCase) 및 기본적인 docstring 추가.
#
# 장기 개선(구조적 재설계)
# - 전체 모듈의 분리
#   - 데이터 모델(User)과 저장소를 분리하고, 비즈니스 로직과 데이터 접근 계층을 분리하는 저장소 인터페이스를 도입.
#   - 저장소를 메모리(dict)에서 DB 연동까지 쉽게 교체 가능하도록 설계.
# - 테스트 주도 개발(TDD) 기반의 단위 테스트 도입
#   - 각 함수/메서드에 대한 단위 테스트 작성으로 경계 조건/입력 유효성 검사 자동화.
# - 스타일/품질 도구 도입
#   - flake8(또는 파이썬 스타일 검사), mypy(정적 타입 검사), pytest를 통한 테스트 자동화.
#
# 3) 전체적인 코드 품질 평가
# - 가독성
#   - 네이밍 불일치, 빌트인 이름 충돌, docstring 부재로 읽기 어려움.
# - 유지보수성
#   - 한 파일에 모여 있는 컴포넌트들로 인해 책임이 얇지 않고, 확장 시 재사용성이 떨어짐.
# - 확장성
#   - 데이터 모델 분리와 저장소 추상화가 부족해 향후 기능 확장에 제약.
# - 성능
#   - find_duplicates의 현재 이중 루프 구조가 가장 큰 병목. 최소한의 대규모 데이터에서 성능 저하가 크게 나타날 가능성.
# - 안정성
#   - 입력 검증 부재로 의도치 않은 데이터가 들어와 예외를 초래할 여지가 있음. get_user에서 KeyError 가능성은 낮지만 안전하지 않음.
# - 테스트
#   - 테스트 부재로 경계조건 회피 및 리팩토링 시 회귀 여부 확인이 어려움.
#
# 4) 구체적인 액션 아이템 제시
# 4.1 단기(1-2주 이내)
# - find_duplicates 개선 1: 매개변수 이름 변경 및 입력 검증 도입
#   - 변경 예시: def find_duplicates(values): → def find_duplicates(items): ...; if items is None: raise ValueError("items must not be None")
# - calculate_average 안정화
#   - 구현 예시: def calculate_average(numbers): if numbers is None: raise ValueError(...); if len(numbers) == 0: raise ValueError(...); return sum(numbers) / len(numbers)
# - 코드 문서화/타입 힌트 추가 시작
#   - 각 함수에 간단한 docstring 추가, 타입 힌트 도입 예비
#
# 4.2 중기(2-6주)
# - find_duplicates를 O(n) 구현으로 완성
#   - 순서 보존 여부에 따라 아래 두 버전 중 선택:
#     - 버전 A(순서 비보존, 간단): seen=set(), duplicates=set(); for v in items: if v in seen: duplicates.add(v); else: seen.add(v); return list(duplicates)
#     - 버전 B(순서 보존, 중복 최초 등장 순서): seen=set(); duplicates=[]; duplicates_set=set(); for v in items: if v in seen: if v not in duplicates_set: duplicates.append(v); duplicates_set.add(v); else: seen.add(v); return duplicates
# - UserManager의 기초 구조 개선 시작
#   - 클래스 이름을 UserManager로 변경, 간단한 dataclass 도입 가능성 탐색
#   - 가능하면 저장소를 dict[name, User] 형태로 전환해 get_user의 평균 복잡도 O(1) 도입 여부 검토
#   - add_user에서 name/age의 기본 유효성 검사 추가
# - calculate_average에 대한 타입 안정성 강화
#   - numbers의 타입 힌트 추가(Sequence[int|float]), 예외 메시지 구체화
# - docstring 및 주석 보강, 기본적인 유닛 테스트 구조 설계
#
# 4.3 장기(6주 이상)
# - 데이터 모델 분리 및 저장소 인터페이스 도입
#   - User 데이터 클래스로 분리, 저장소를 메모리/DB로 쉽게 교체 가능한 구조 설계
# - 테스트 주도 개발 적용
#   - pytest 기반의 단위 테스트 작성
# - 코드 품질 도구 자동화
#   - CI에 flake8/mypy/pytest 연동 및 PR 가이드라인 마련
#
# 4.4 도구와 프로세스
# - 스타일/정합성 도구 도입
#   - flake8로 스타일 검사, mypy로 타입 검사
# - 테스트 자동화
#   - pytest를 기본 테스트 프레임워크로 도입하고, 각 모듈에 테스트 커버리지 목표 설정
# - 지속적인 성능 측정
#   - timeit/cProfile 기반 벤치마크 스크립트 작성 및 주기적 회귀 테스트에 포함
#
# 4.5 간단한 테스트 아이디어(참고)
# - find_duplicates([1, 2, 2, 3, 4, 4]) → [2, 4] (순서 보존 버전일 때)
# - calculate_average([1, 2, 3, 4]) → 2.5
# - calculate_average([]) → 예외 발생
# - UserManager 예시:
#   - um = UserManager(); um.add_user("Alice", 30); um.get_user("Alice") == UserTree/데이터 객체
#   - 중복 추가 시 정책에 따라 예외 또는 갱신 여부 결정
#
# 4.6 실행 예시(핵심 개선 버전 아이디어)
# - find_duplicates(순서 보존 버전 예시)
#   def find_duplicates(items):
#       seen = set()
#       duplicates = []
#       duplicates_seen = set()
#       for item in items:
#           if item in seen:
#               if item not in duplicates_seen:
#                   duplicates.append(item)
#                   duplicates_seen.add(item)
#           else:
#               seen.add(item)
#       return duplicates
# - calculate_average 간단 개선 예시
#   def calculate_average(numbers):
#       if numbers is None or len(numbers) == 0:
#           raise ValueError("numbers must not be empty")
#       return sum(numbers) / len(numbers)
# - UserManager 간단 데이터 모델 예시(데이터 클래스 + dict 저장소)
#   from dataclasses import dataclass
#   from typing import Optional, Dict
#
#   @dataclass
#   class User:
#       name: str
#       age: int
#
#   class UserManager:
#       def __init__(self) -> None:
#           self._users: Dict[str, User] = {}
#
#       def add_user(self, name: str, age: int) -> None:
#           if name is None or age is None:
#               raise ValueError("name과 age는 None일 수 없습니다")
#           if not isinstance(name, str) or not isinstance(age, int) or age < 0:
#               raise ValueError("Invalid user data: name은 str, age는 음수가 아닌 int이어야 합니다")
#           self._users[name] = User(name, age)
#
#       def get_user(self, name: str) -> Optional[User]:
#           return self._users.get(name)
#
# 최종 요약
# - 현재 코드는 소규모 유틸리티와 간단한 저장소가 한 파일에 모여 구조적 취약점을 내포하고 있습니다.
# - 개선 방향의 핵심은: 명확한 네이밍 규칙(Pep8), None/유효성 검사 강화, 빌트인 이름 충돌 제거, 성능 병목의 주된 원인인 find_duplicates의 O(n) 구현, 그리고 데이터 모델과 저장소를 분리한 확장 가능한 구조로의 전환입니다.
# - 실행 로드맷은 먼저(1) 단기 고효율 개선, (2) 중기 구조적 리팩토링, (3) 장기 모듈화 및 테스트 도입의 순서로 제안합니다.
# - 스타일/품질 도구 도입(flake8, mypy, pytest)과 테스트 커버리지 목표 설정은 타임라인에 포함하는 것을 권장합니다.
#
# 필요하시면 위 개선안을 반영한 전체 통합 코드 버전 또는 구체적인 PR 패키징 가이드, 벤치마크 스크립트와 테스트 예시도 함께 제공해 드리겠습니다.
#
# ================================================================================

# %% [markdown]
# ## 8. 재사용 가능한 리뷰 함수

# %%
def review_code(code: str, show_individual_reviews: bool = False):
    """
    코드를 리뷰하는 함수
    
    Args:
        code: 리뷰할 코드
        show_individual_reviews: 개별 리뷰 결과 표시 여부
    
    Returns:
        리뷰 결과 딕셔너리
    """
    print("\n" + "=" * 80)
    print("코드 리뷰 시작")
    print("=" * 80)
    
    initial_state = {
        "code": code,
        "reviews": [],
        "final_report": ""
    }
    
    result = app.invoke(initial_state)
    
    if show_individual_reviews:
        print("\n[개별 리뷰 결과]")
        for i, review in enumerate(result["reviews"], 1):
            print(f"\n--- 리뷰 {i} ---")
            print(review)
    
    print("\n" + "=" * 80)
    print("[최종 통합 리포트]")
    print("=" * 80)
    print(result["final_report"])
    print("=" * 80)
    
    return result

# 사용 예시
# review_code(your_code, show_individual_reviews=True)
